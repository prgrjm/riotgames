# %%
import requests
import pandas

# %%
api_key = "?api_key=RGAPI-4047af90-14ee-4b48-8b5d-6eca72944062"

# %%
alpha = requests.get('https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5' + api_key)

# %%
beta = pandas.DataFrame(alpha.json())

# %%
beta
# Out:
#           tier                              leagueId            queue  \
# 0   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 1   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 2   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 3   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 4   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 5   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 6   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 7   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 8   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 9   CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 10  CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# 11  CHALLENGER  05fb99f4-e149-3133-a78e-821597582f9d  RANKED_SOLO_5x5
# ...

# %%
gamma = pandas.DataFrame(dict(beta['entries']))

# %%
gamma
# Out:
#                                                            0   \
# summonerId    CP_TdYTN1UVX3U-9pDrE89gyN4rfnA0dNwRbNWFvfxZov1o
# summonerName                                     Slow start 1
# leaguePoints                                              556
# rank                                                        I
# wins                                                       94
# losses                                                     81
# veteran                                                 False
# inactive                                                False
# freshBlood                                               True
# hotStreak                                               False
#
#                                                             1   \
# summonerId    kdD26lftcteTq8WgcGs1GZ5ZsiYJ6Halx-YNqOazLszEyd68
# summonerName                                   zhang lang e ba
# leaguePoints                                               902
# ...

# %%
gamma.transpose()
# Out:
#                                            summonerId      summonerName  \
# 0     CP_TdYTN1UVX3U-9pDrE89gyN4rfnA0dNwRbNWFvfxZov1o      Slow start 1
# 1    kdD26lftcteTq8WgcGs1GZ5ZsiYJ6Halx-YNqOazLszEyd68   zhang lang e ba
# 2     jdQUOeASFDH2g8N1NA3VuP5CpgVJQMuJ5c9JoPqKHewhJTk            탑 가엔싸개
# 3   4YDe2tzQgT-tRwow3d-bJe1zLfCMkI-lRUXbUn9r7ZkA9J...          마쎄옐로우3미리
# 4     9HV6BAjUE-wG-Lw5b7pvlkzspK_GYl71VyrptmVpjsV_Y1k             달리기 왕
# 5   SBrPtXleYtkbYmQ3MQwd6sW2Yv8e2f3jkHDHbpw2_BMYlO...       CscyDzhbzBZ
# 6     Cy1QmjoawfDY1guuDxwGAHvlDSQ-R_yUO-rLrIsbJAlU6mQ             권 지 인
# 7   kGKVr6q3ujKSGZwkpoCU5Ed9AZ0mT7-Ub-iD0nreq3NYpM...            땅에 묻히다
# 8     h93ifWvzw3o4YgALa7ap8ICtpH1_Wa5x_PAcXIOK_Wz0j5E               누쇤퍅
# 9   9nBnJchMoGZ7S4014cHRI2ZIArq1MYhMJ8i3a385BUuBpv...    Epilogue for u
# 10    _jVIND56pKe6pstPfbEgB2iKLhf5IewpPo8FOILr3H9IQ1E          패배를까먹은사람
# 11  U35E-tD_IJ2gP4Rs7xGugcvIsDerdoosvz9y1Eknz_rYG9...         trimester
# ...
